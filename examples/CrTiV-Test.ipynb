# %%
# %matplotlib inline
from pycalphad import Database, eq, isotherm
from pycalphad.variables import *

db = Database('crtiv_ghosh.tdb')
# %time sys_df = eq(db, ['CR', 'TI', 'V', 'VA'] , ['LAVES_C14', 'LAVES_C15', 'BCC_A2', 'HCP_A3', 'LAVES_C36'], T=873, points_per_phase=30000, ast='numpy')
# Out:
# CPU times: user 9.06 s, sys: 44 ms, total: 9.1 s
# Wall time: 9.1 s

# %%
# %time isotherm(sys_df, 'X(V)','X(TI)', T=873)
# Out:
#             X(V)     X(TI)            GM      Phase
# 0       0.000000  0.358675 -22085.429315  LAVES_C14
# 1       0.000000  0.390703 -22898.555625  LAVES_C14
# 2       0.000000  0.511718 -28443.829256  LAVES_C14
# 3       0.000000  0.399211 -23159.170061  LAVES_C14
# 4       0.000000  0.590437 -34015.162475  LAVES_C14
# 5       0.000000  0.365300 -22232.409186  LAVES_C14
# 6       0.000000  0.561839 -31853.859119  LAVES_C14
# 7       0.000000  0.308929 -21289.780443  LAVES_C14
# 8       0.000000  0.307706 -21275.626781  LAVES_C14
# 9       0.000000  0.302762 -21219.713770  LAVES_C14
# 10      0.000000  0.451390 -25183.910531  LAVES_C14
# 11      0.000000  0.304615 -21240.459201  LAVES_C14
# 12      0.000000  0.463698 -25769.485927  LAVES_C14
# 13      0.000000  0.278307 -20893.550362  LAVES_C14
# 14      0.000000  0.590912 -34051.582244  LAVES_C14
# 15      0.000000  0.584339 -33547.482607  LAVES_C14
# 16      0.000000  0.491404 -27237.738263  LAVES_C14
# 17      0.000000  0.441887 -24759.994550  LAVES_C14
# 18      0.000000  0.323910 -21479.339944  LAVES_C14
# 19      0.000000  0.302014 -21211.387612  LAVES_C14
# 20      0.000000  0.441674 -24750.771473  LAVES_C14
# 21      0.000000  0.576547 -32953.356533  LAVES_C14
# 22      0.000000  0.316745 -21384.508466  LAVES_C14
# 23      0.000000  0.352707 -21962.130416  LAVES_C14
# 24      0.000000  0.558021 -31574.519744  LAVES_C14
# 25      0.000000  0.532299 -29773.069093  LAVES_C14
# 26      0.000000  0.467860 -25976.826338  LAVES_C14
# 27      0.000000  0.358921 -22090.709254  LAVES_C14
# 28      0.000000  0.603441 -35000.883615  LAVES_C14
# 29      0.000000  0.430092 -24268.132472  LAVES_C14
# ...          ...       ...           ...        ...
# 149757  0.067721  0.512961 -32262.790619     HCP_A3
# 149758  0.544451  0.147773 -33841.338157     HCP_A3
# 149759  0.445001  0.484459 -35773.422470     HCP_A3
# 149760  0.101163  0.351718 -31283.045352     HCP_A3
# 149761  0.094453  0.432503 -31934.378029     HCP_A3
# 149762  0.642674  0.252324 -34599.139916     HCP_A3
# 149763  0.129641  0.300098 -31333.177883     HCP_A3
# 149764  0.033874  0.147396 -28216.401189     HCP_A3
# 149765  0.430515  0.538772 -35921.689966     HCP_A3
# 149766  0.058920  0.445275 -31320.561648     HCP_A3
# 149767  0.086257  0.909483 -37339.608416     HCP_A3
# 149768  0.287446  0.362909 -33948.304673     HCP_A3
# 149769  0.193283  0.638156 -35786.981322     HCP_A3
# 149770  0.613581  0.245822 -34624.727302     HCP_A3
# 149771  0.268673  0.401992 -34118.748761     HCP_A3
# 149772  0.831055  0.105899 -33196.524161     HCP_A3
# 149773  0.456616  0.487099 -35755.322078     HCP_A3
# 149774  0.472379  0.183474 -33821.837815     HCP_A3
# 149775  0.883890  0.111203 -32413.783885     HCP_A3
# 149776  0.114907  0.415213 -32138.313240     HCP_A3
# 149777  0.065298  0.190401 -29264.561863     HCP_A3
# 149778  0.354679  0.524372 -35877.125737     HCP_A3
# 149779  0.293407  0.155461 -32235.629693     HCP_A3
# 149780  0.748926  0.230485 -33819.317107     HCP_A3
# 149781  0.087944  0.857491 -37081.434469     HCP_A3
# 149782  0.112110  0.465594 -32610.990902     HCP_A3
# 149783  0.933934  0.045256 -31878.156323     HCP_A3
# 149784  0.127598  0.156363 -30149.446168     HCP_A3
# 149785  0.845916  0.013583 -32361.526051     HCP_A3
# 149786  0.265596  0.334422 -33466.865757     HCP_A3
#
# [149787 rows x 4 columns]
# CPU times: user 12.6 s, sys: 24 ms, total: 12.7 s
# Wall time: 12.6 s
