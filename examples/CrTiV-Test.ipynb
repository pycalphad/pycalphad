# %%
# %matplotlib inline
from pycalphad import Database, eq, isotherm
from pycalphad.variables import *

db = Database('crtiv_ghosh.tdb')
# %time sys_df = eq(db, ['CR', 'TI', 'V', 'VA'] , ['LAVES_C14', 'LAVES_C15', 'BCC_A2', 'HCP_A3', 'LAVES_C36'], T=873, points_per_phase=30000, ast='numpy')
# Out:
# CPU times: user 13.8 s, sys: 42 ms, total: 13.8 s
# Wall time: 13.9 s

# %%
# %time isotherm(sys_df, 'X(V)','X(TI)', T=873)
# Out:
#             X(V)     X(TI)            GM   Phase
# 0       0.172834  0.013930 -29252.121471  HCP_A3
# 1       0.414000  0.319715 -34572.840550  HCP_A3
# 2       0.234770  0.522452 -34964.799835  HCP_A3
# 3       0.466112  0.374728 -35204.416366  HCP_A3
# 4       0.586320  0.168060 -34120.633970  HCP_A3
# 5       0.188985  0.609959 -35415.847329  HCP_A3
# 6       0.657304  0.280831 -34587.961335  HCP_A3
# 7       0.254925  0.493770 -34877.449442  HCP_A3
# 8       0.668944  0.247731 -34489.565306  HCP_A3
# 9       0.755455  0.047871 -33114.903171  HCP_A3
# 10      0.874464  0.106981 -32658.442637  HCP_A3
# 11      0.371590  0.240405 -33639.511043  HCP_A3
# 12      0.555377  0.125645 -33688.228098  HCP_A3
# 13      0.626905  0.139311 -33970.565646  HCP_A3
# 14      0.104725  0.580809 -33814.318413  HCP_A3
# 15      0.048396  0.564278 -32434.004027  HCP_A3
# 16      0.266053  0.698991 -36769.150221  HCP_A3
# 17      0.000640  0.417101 -29291.273354  HCP_A3
# 18      0.427764  0.185080 -33577.023463  HCP_A3
# 19      0.038449  0.090870 -27879.060231  HCP_A3
# 20      0.152874  0.007012 -28828.285908  HCP_A3
# 21      0.169263  0.634509 -35462.771079  HCP_A3
# 22      0.116320  0.171013 -30078.559941  HCP_A3
# 23      0.293284  0.607058 -36256.381326  HCP_A3
# 24      0.098316  0.362882 -31331.444919  HCP_A3
# 25      0.314902  0.618630 -36403.488193  HCP_A3
# 26      0.119673  0.621365 -34581.461554  HCP_A3
# 27      0.564795  0.199924 -34302.959180  HCP_A3
# 28      0.445195  0.094296 -32855.464396  HCP_A3
# 29      0.328432  0.318140 -33935.497639  HCP_A3
# ...          ...       ...           ...     ...
# 149757  0.293710  0.303988 -40336.228130  BCC_A2
# 149758  0.044001  0.012903 -32646.708574  BCC_A2
# 149759  0.565515  0.066256 -41739.375807  BCC_A2
# 149760  0.358963  0.531563 -40389.963387  BCC_A2
# 149761  0.104543  0.793531 -38694.103403  BCC_A2
# 149762  0.850496  0.080065 -40105.889123  BCC_A2
# 149763  0.466531  0.132695 -41327.121927  BCC_A2
# 149764  0.678471  0.035955 -41838.900419  BCC_A2
# 149765  0.084228  0.316633 -37540.086043  BCC_A2
# 149766  0.362838  0.491236 -40577.732694  BCC_A2
# 149767  0.032153  0.923263 -37202.128965  BCC_A2
# 149768  0.164539  0.623631 -39619.878793  BCC_A2
# 149769  0.766008  0.175180 -40381.236357  BCC_A2
# 149770  0.252101  0.433234 -40209.715420  BCC_A2
# 149771  0.128808  0.212735 -37794.347133  BCC_A2
# 149772  0.256844  0.262753 -39907.711402  BCC_A2
# 149773  0.251446  0.526578 -40221.363888  BCC_A2
# 149774  0.205065  0.203663 -39055.746580  BCC_A2
# 149775  0.297316  0.106767 -39866.510452  BCC_A2
# 149776  0.118113  0.680317 -39184.452813  BCC_A2
# 149777  0.354661  0.008050 -39857.483261  BCC_A2
# 149778  0.172193  0.826181 -37988.363478  BCC_A2
# 149779  0.029683  0.403565 -36751.741895  BCC_A2
# 149780  0.584955  0.134838 -41695.530208  BCC_A2
# 149781  0.285376  0.455843 -40425.401726  BCC_A2
# 149782  0.491653  0.108464 -41452.094233  BCC_A2
# 149783  0.152036  0.491954 -39398.649582  BCC_A2
# 149784  0.596522  0.320108 -40791.066596  BCC_A2
# 149785  0.559321  0.256164 -41326.568129  BCC_A2
# 149786  0.394467  0.171402 -40910.620324  BCC_A2
#
# [149787 rows x 4 columns]
# CPU times: user 12.2 s, sys: 24 ms, total: 12.2 s
# Wall time: 12.4 s
