# %%
# %matplotlib inline
from pycalphad import Database, eq, isotherm
from pycalphad.variables import *

db = Database('crtiv_ghosh.tdb')
# %time sys_df = eq(db, ['CR', 'TI', 'V', 'VA'] , ['LAVES_C14', 'LAVES_C15', 'BCC_A2', 'HCP_A3', 'LAVES_C36'], T=873, points_per_phase=30000, ast='numpy')
# Out:
# [BCC_A20CR, BCC_A20V, BCC_A20TI, BCC_A21VA]
# [LAVES_C140CR, LAVES_C140TI, LAVES_C141CR, LAVES_C141TI]
# [LAVES_C150CR, LAVES_C150V, LAVES_C150TI, LAVES_C151CR, LAVES_C151V, LAVES_C151TI]
# [LAVES_C360CR, LAVES_C360V, LAVES_C360TI, LAVES_C361CR, LAVES_C361V, LAVES_C361TI]
# [HCP_A30CR, HCP_A30V, HCP_A30TI, HCP_A31VA]
# CPU times: user 6.15 s, sys: 35 ms, total: 6.19 s
# Wall time: 6.18 s

# %%
# %time isotherm(sys_df, 'X(V)','X(TI)', T=873)
# Out:
#             X(V)     X(TI)            GM   Phase
# 0       0.353162  0.522498 -40446.043372  BCC_A2
# 1       0.149155  0.284542 -38583.387548  BCC_A2
# 2       0.140844  0.060369 -36737.389443  BCC_A2
# 3       0.252035  0.589756 -40099.938336  BCC_A2
# 4       0.063357  0.759258 -38480.981234  BCC_A2
# 5       0.078919  0.737600 -38705.301483  BCC_A2
# 6       0.400847  0.248031 -40985.783630  BCC_A2
# 7       0.321889  0.055925 -39916.024084  BCC_A2
# 8       0.585655  0.020450 -41690.751147  BCC_A2
# 9       0.793097  0.054428 -41180.676714  BCC_A2
# 10      0.633511  0.040257 -41853.910098  BCC_A2
# 11      0.001176  0.214670 -33932.730857  BCC_A2
# 12      0.129444  0.362667 -38640.380367  BCC_A2
# 13      0.104346  0.579778 -38996.360163  BCC_A2
# 14      0.294271  0.043283 -39465.683640  BCC_A2
# 15      0.066717  0.483943 -38081.967893  BCC_A2
# 16      0.323060  0.329467 -40580.589240  BCC_A2
# 17      0.307728  0.194288 -40240.982215  BCC_A2
# ...
