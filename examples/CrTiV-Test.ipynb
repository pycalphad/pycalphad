# %%
# %matplotlib inline
from pycalphad import Database, energy_surf, isotherm
from pycalphad.variables import *

db = Database('crtiv_ghosh.tdb')
# %time sys_df = energy_surf(db, ['CR', 'TI', 'V', 'VA'] , ['LAVES_C14', 'LAVES_C15', 'BCC_A2', 'HCP_A3', 'LAVES_C36'], T=873, points_per_phase=50000, ast='numpy')
# Out:
# CPU times: user 6.88 s, sys: 4 ms, total: 6.89 s
# Wall time: 6.88 s

# %%
# %time isotherm(sys_df, 'X(V)','X(TI)', T=873)
# Out:
#             X(V)     X(TI)        GM      Phase
# 0       0.502686  0.129461 -33508.95     HCP_A3
# 1       0.153483  0.752604 -36655.03     HCP_A3
# 2       0.308618  0.147868 -32315.84     HCP_A3
# 3       0.026970  0.643572 -32913.15     HCP_A3
# 4       0.345222  0.476413 -35443.49     HCP_A3
# 5       0.627136  0.217675 -34475.23     HCP_A3
# 6       0.499008  0.284889  -34703.8     HCP_A3
# 7       0.338089  0.468520 -35330.52     HCP_A3
# 8       0.405567  0.057114  -32170.8     HCP_A3
# 9       0.377318  0.013925 -31279.43     HCP_A3
# 10      0.013911  0.398143 -29634.57     HCP_A3
# 11      0.482745  0.296626 -34728.73     HCP_A3
# 12      0.288461  0.475686 -35014.93     HCP_A3
# 13      0.589829  0.279623 -34799.97     HCP_A3
# 14      0.153961  0.382568 -32466.24     HCP_A3
# 15      0.054945  0.184998 -28998.73     HCP_A3
# 16      0.166450  0.764216 -36881.11     HCP_A3
# 17      0.544655  0.013987 -32232.64     HCP_A3
# 18      0.072196  0.035258 -28013.58     HCP_A3
# 19      0.622546  0.057778 -33177.49     HCP_A3
# 20      0.258677  0.140751 -31748.85     HCP_A3
# 21      0.428495  0.297385 -34480.88     HCP_A3
# 22      0.434679  0.001019 -31317.55     HCP_A3
# 23      0.115181  0.169582  -30048.1     HCP_A3
# 24      0.513419  0.032837 -32445.12     HCP_A3
# 25      0.198015  0.386313 -33134.15     HCP_A3
# 26      0.503580  0.460100 -35506.77     HCP_A3
# 27      0.100798  0.423079 -31959.37     HCP_A3
# 28      0.618159  0.260225 -34682.82     HCP_A3
# 29      0.088089  0.339300 -30921.21     HCP_A3
# ...          ...       ...       ...        ...
# 249157  0.000000  0.314250  -29521.1  LAVES_C14
# 249158  0.000000  0.430612 -37491.32  LAVES_C14
# 249159  0.000000  0.180466 -24567.04  LAVES_C14
# 249160  0.000000  0.435107 -37820.58  LAVES_C14
# 249161  0.000000  0.241129 -26220.29  LAVES_C14
# 249162  0.000000  0.312922 -29448.21  LAVES_C14
# 249163  0.000000  0.109981 -23579.86  LAVES_C14
# 249164  0.000000  0.115913 -23668.17  LAVES_C14
# 249165  0.000000  0.224889 -25683.93  LAVES_C14
# 249166  0.000000  0.412503 -36109.45  LAVES_C14
# 249167  0.000000  0.349695 -31637.31  LAVES_C14
# 249168  0.000000  0.168491  -24348.2  LAVES_C14
# 249169  0.000000  0.214638 -25381.41  LAVES_C14
# 249170  0.000000  0.179681  -24551.7  LAVES_C14
# 249171  0.000000  0.295582 -28540.28  LAVES_C14
# 249172  0.000000  0.274847 -27561.61  LAVES_C14
# 249173  0.000000  0.264132 -27101.82  LAVES_C14
# 249174  0.000000  0.425444 -37100.78  LAVES_C14
# 249175  0.000000  0.368595 -32895.37  LAVES_C14
# 249176  0.000000  0.205131 -25125.32  LAVES_C14
# 249177  0.000000  0.199106 -24975.02  LAVES_C14
# 249178  0.000000  0.236637 -26064.88  LAVES_C14
# 249179  0.000000  0.313293 -29468.51  LAVES_C14
# 249180  0.000000  0.436899  -37945.9  LAVES_C14
# 249181  0.000000  0.201701 -25038.62  LAVES_C14
# 249182  0.000000  0.282463 -27907.45  LAVES_C14
# 249183  0.000000  0.153707 -24120.28  LAVES_C14
# 249184  0.000000  0.134507 -23880.53  LAVES_C14
# 249185  0.000000  0.436529 -37920.46  LAVES_C14
# 249186  0.000000  0.424735 -37046.75  LAVES_C14
#
# [249187 rows x 4 columns]
# CPU times: user 21.7 s, sys: 38 ms, total: 21.8 s
# Wall time: 21.7 s
