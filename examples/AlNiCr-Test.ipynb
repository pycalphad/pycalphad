# %%
# %matplotlib inline
from pycalphad import Database, energy_surf, isotherm
from pycalphad.variables import *

db = Database('alcrni_dup.tdb')
my_phases = ['LIQUID', 'FCC_A1', 'BCC_A2']
# %time sys_df = energy_surf(db, ['CR', 'AL', 'NI', 'VA'] , my_phases, T=1573, points_per_phase=30000, ast='numpy')
# Out:
# CPU times: user 7.94 s, sys: 12 ms, total: 7.95 s
# Wall time: 7.94 s

# %%
# %time isotherm(sys_df, 'X(CR)','X(AL)', T=1573)
# Out:
#           X(CR)     X(AL)             GM   Phase
# 0      0.213728  0.749384 -102284.367886  LIQUID
# 1      0.049692  0.292972 -123670.930618  LIQUID
# 2      0.229235  0.094524 -103822.471452  LIQUID
# 3      0.818346  0.052048  -80873.175657  LIQUID
# 4      0.165781  0.397534 -124875.499011  LIQUID
# 5      0.745609  0.154068  -87271.200065  LIQUID
# 6      0.169355  0.257238 -119112.534510  LIQUID
# 7      0.506626  0.290195 -103642.784326  LIQUID
# 8      0.713455  0.123270  -88895.366260  LIQUID
# 9      0.147208  0.437451 -126165.408507  LIQUID
# 10     0.290429  0.702186  -98777.870572  LIQUID
# 11     0.308745  0.404988 -116377.844203  LIQUID
# 12     0.248568  0.397420 -120308.398616  LIQUID
# 13     0.485852  0.014925  -90768.271810  LIQUID
# 14     0.126345  0.540525 -125834.808168  LIQUID
# 15     0.586861  0.109429  -94899.687413  LIQUID
# 16     0.381539  0.579729 -101231.627785  LIQUID
# 17     0.130216  0.388755 -126336.857332  LIQUID
# 18     0.505770  0.089281  -96928.860415  LIQUID
# 19     0.332650  0.118194 -104432.693844  LIQUID
# 20     0.212057  0.245271 -117159.690339  LIQUID
# 21     0.162619  0.621573 -118999.360885  LIQUID
# 22     0.167800  0.654491 -116144.477617  LIQUID
# 23     0.813893  0.137643  -82373.052168  LIQUID
# 24     0.786317  0.069455  -83246.505268  LIQUID
# 25     0.141480  0.497137 -125992.747636  LIQUID
# 26     0.090709  0.110953 -105714.105248  LIQUID
# 27     0.048743  0.692931 -122917.484134  LIQUID
# 28     0.241360  0.056795  -99369.258218  LIQUID
# 29     0.054467  0.331333 -126158.904681  LIQUID
# ...         ...       ...            ...     ...
# 89970  0.515763  0.397776  -98161.440216  FCC_A1
# 89971  0.799279  0.196961  -81988.986507  FCC_A1
# 89972  0.286712  0.614926 -103364.884810  FCC_A1
# 89973  0.273121  0.722863  -93267.455061  FCC_A1
# 89974  0.224250  0.768085  -93021.291545  FCC_A1
# 89975  0.420878  0.164657 -104426.546459  FCC_A1
# 89976  0.598049  0.038187  -89806.923218  FCC_A1
# 89977  0.168458  0.309834 -120393.880107  FCC_A1
# 89978  0.531962  0.099432  -96462.251246  FCC_A1
# 89979  0.029424  0.425368 -127769.455065  FCC_A1
# 89980  0.561447  0.103295  -95416.960410  FCC_A1
# 89981  0.481673  0.373798 -101830.386522  FCC_A1
# 89982  0.164697  0.614240 -113652.404601  FCC_A1
# 89983  0.660714  0.050579  -88129.740439  FCC_A1
# 89984  0.267877  0.467317 -113961.752698  FCC_A1
# 89985  0.740521  0.031665  -83357.908631  FCC_A1
# 89986  0.672257  0.183398  -91711.278723  FCC_A1
# 89987  0.155889  0.756777 -101538.785233  FCC_A1
# 89988  0.281768  0.072975 -101644.690369  FCC_A1
# 89989  0.625061  0.137099  -93686.080111  FCC_A1
# 89990  0.669749  0.160133  -91662.129254  FCC_A1
# 89991  0.018047  0.950892  -88985.552472  FCC_A1
# 89992  0.460958  0.235200 -104622.927158  FCC_A1
# 89993  0.061864  0.337072 -124872.504881  FCC_A1
# 89994  0.210535  0.266041 -117242.069747  FCC_A1
# 89995  0.063136  0.793809 -105673.209556  FCC_A1
# 89996  0.122505  0.808780  -98650.777291  FCC_A1
# 89997  0.038913  0.864778  -99291.206125  FCC_A1
# 89998  0.022545  0.444471 -128065.717279  FCC_A1
# 89999  0.917366  0.048867  -74070.222319  FCC_A1
#
# [90000 rows x 4 columns]
# CPU times: user 5.73 s, sys: 10 ms, total: 5.74 s
# Wall time: 5.74 s

# %%
# Perform some setup for phase-specific coloring of points
import numpy as np
colorlist = {}

# colors from Junwei Huang, March 21 2013
ColorValues=["FF0000", "00FF00", "0000FF", "FFFF00", "FF00FF", "00FFFF", "000000", 
        "800000", "008000", "000080", "808000", "800080", "008080", "808080", 
        "C00000", "00C000", "0000C0", "C0C000", "C000C0", "00C0C0", "C0C0C0", 
        "400000", "004000", "000040", "404000", "400040", "004040", "404040", 
        "200000", "002000", "000020", "202000", "200020", "002020", "202020", 
        "600000", "006000", "000060", "606000", "600060", "006060", "606060", 
        "A00000", "00A000", "0000A0", "A0A000", "A000A0", "00A0A0", "A0A0A0", 
        "E00000", "00E000", "0000E0", "E0E000", "E000E0", "00E0E0", "E0E0E0"]
M=len(ColorValues)

phasecount = 0
for phase in my_phases:
	colorlist[phase] = "#"+ColorValues[np.mod(phasecount,M)]
	phasecount = phasecount + 1

# Get the configured plot colors
plotcolors = list(map(lambda x: colorlist[x], sys_df['Phase'].values))

# %%
# Final plotting setup
import numpy as np
import matplotlib.pyplot as plt
import scipy.spatial
x_variable = 'X(CR)'
y_variable = 'X(AL)'
hull = scipy.spatial.ConvexHull(
    sys_df[['X(CR)', 'X(AL)', 'GM']].values
)
fig = plt.figure(dpi=600,figsize=(9,9))
ax = fig.gca(projection="triangular") # use ternary axes
ax.tick_params(axis='both', which='major', labelsize=14)
ax.grid(True)
plt.xlim([-0.01,1])
plt.ylim([-0.01,1])
plt.gca().set_aspect('equal')

ax.text(0.3, 0.8, 'T = '+str(sys_df['T'][0])+ ' K',
        verticalalignment='bottom', horizontalalignment='left',
        color='black', fontsize=20)

stable_df = sys_df.ix[np.unique(np.ravel(hull.vertices))]
for phase in my_phases:
    # Plot each phase separately so we can mark the legend properly
    phase_frame = stable_df[(stable_df.Phase == phase)]
    if (len(phase_frame) > 0):
        ax.scatter(phase_frame[x_variable], phase_frame[y_variable], c=colorlist[phase],
                       marker='o',
                       label=phase,
                       zorder=2, alpha=0.4)
        ax.legend(loc=0, fontsize=15)
plt.title('Energy Surface',fontsize=25, x=0.5, y=0.9)
ax.set_xlabel(x_variable, labelpad=15,fontsize=20)
ax.set_ylabel(y_variable,rotation=60,fontsize=20,labelpad=-120)
plt.show()
