# %%
# %matplotlib inline
from pycalphad import Database, binplot

db = Database('alni_oht.TDB')
my_phases = ['BCC_A2', 'FCC_A1', 'K_carbide', 'AL3NI2', 'AL3NI1', 'AL3NI5', 'LIQUID']
# %time binplot(db, ['AL', 'NI', 'VA'] , my_phases, 'X(AL)', 300, 2000, points_per_phase=5000, steps=50)
# Out:
# CPU times: user 25.8 s, sys: 145 ms, total: 25.9 s
# Wall time: 25.9 s
