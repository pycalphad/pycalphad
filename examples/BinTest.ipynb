# %%
# %matplotlib inline
from pycalphad import Database, binplot

db = Database('alzn_mey.tdb')
my_phases = ['LIQUID', 'FCC_A1', 'HCP_A3']
# %time %memit binplot(db, ['AL', 'ZN', 'VA'] , my_phases, 'X(ZN)', 300, 1000)
# Out:
# peak memory: 119.27 MiB, increment: 11.70 MiB
# CPU times: user 1.04 s, sys: 15 ms, total: 1.05 s
# Wall time: 1.16 s
