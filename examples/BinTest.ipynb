# %%
# %matplotlib inline
from pycalphad import Database, binplot

db = Database('alzn_mey.tdb')
my_phases = ['FCC_A1', 'HCP_A3', 'LIQUID']
# %time binplot(db, ['AL', 'ZN', 'VA'] , my_phases, 'X(ZN)', 300, 1000, steps=200)
# Out:
# CPU times: user 28.6 s, sys: 26 ms, total: 28.6 s
# Wall time: 28.6 s
