# %%
# %matplotlib inline
from pycalphad import Database, binplot

db = Database('alzn_mey.tdb')
my_phases = ['FCC_A1', 'HCP_A3', 'LIQUID']
# %time binplot(db, ['AL', 'ZN', 'VA'] , my_phases, 'X(ZN)', 300, 1000)
# Out:
# CPU times: user 10 s, sys: 7 ms, total: 10.1 s
# Wall time: 10 s
