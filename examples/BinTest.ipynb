# %%
# %matplotlib inline
from pycalphad import Database, binplot

db = Database('alzn_mey.tdb')
my_phases = ['LIQUID', 'FCC_A1', 'HCP_A3']
# %time %memit binplot(db, ['AL', 'ZN', 'VA'] , my_phases, 'X(ZN)', 300, 1000, points_per_phase=100)
# Out:
# peak memory: 129.25 MiB, increment: 8.86 MiB
# CPU times: user 845 ms, sys: 19 ms, total: 864 ms
# Wall time: 970 ms
