# %%
# %matplotlib inline
from pycalphad import Database, binplot, energy_surf

db = Database('alzn_mey.tdb')
my_phases = ['FCC_A1', 'HCP_A3', 'LIQUID']
# %time binplot(db, ['AL', 'ZN', 'VA'] , my_phases, 'X(ZN)', 300, 1000, steps=200, ast='numpy')
# Out:
# CPU times: user 21.9 s, sys: 23 ms, total: 21.9 s
# Wall time: 21.8 s
