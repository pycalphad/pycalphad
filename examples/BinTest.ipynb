# %%
# %matplotlib inline
from pycalphad import Database, binplot

db = Database('alzn_mey.tdb')
my_phases = ['LIQUID', 'FCC_A1', 'HCP_A3']
# %time binplot(db, ['AL', 'ZN', 'VA'] , my_phases, 'X(ZN)', 300, 1000, points_per_phase=2000, ast='numexpr')
# Out:
# CPU times: user 5.61 s, sys: 36 ms, total: 5.65 s
# Wall time: 5.64 s
