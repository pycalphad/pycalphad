# %%
# %matplotlib inline
from pycalphad import Database, binplot

db = Database('alzn_mey.tdb')
my_phases = ['LIQUID', 'FCC_A1', 'HCP_A3']
# %time binplot(db, ['AL', 'ZN', 'VA'] , my_phases, 'X(ZN)', 300, 1000, points_per_phase=2000, ast='numpy')
# Out:
# CPU times: user 5.56 s, sys: 24 ms, total: 5.58 s
# Wall time: 5.57 s
