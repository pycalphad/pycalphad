# %%
# %matplotlib inline
from pycalphad import Database, binplot

db = Database('alzn_mey.tdb')
my_phases = ['LIQUID', 'FCC_A1', 'HCP_A3']
# %time binplot(db, ['AL', 'ZN', 'VA'] , my_phases, 'X(ZN)', 300, 1000, points_per_phase=3000)
# Out:
# CPU times: user 48.6 s, sys: 50 ms, total: 48.7 s
# Wall time: 48.6 s
