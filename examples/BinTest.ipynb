# %%
# %matplotlib inline
from pycalphad import Database, binplot
import mpld3
mpld3.enable_notebook()

db = Database('alzn_mey.tdb')
my_phases = ['FCC_A1', 'HCP_A3', 'LIQUID']
fig = binplot(db, ['AL', 'ZN', 'VA'] , my_phases, 'X(ZN)', 300, 1000, steps=200, mpld3=True)
mpld3.display(fig)
#binplot(db, ['AL', 'ZN', 'VA'] , my_phases, 'X(ZN)', 300, 1000, steps=200)
