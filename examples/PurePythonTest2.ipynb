# %%
# %matplotlib inline
from pycalphad.io.tdb import tdbread
from pycalphad import Database, eq, isotherm
from pycalphad.variables import *

db = Database()
tdbread(db, open('crfeni_mie.tdb').read())
# %time sys_df = eq(db, ['FE', 'CR', 'NI', 'VA'] , ['BCC_A2', 'FCC_A1'], T=400, points_per_phase=10000, ast='numpy')
# Out:
# [BCC_A20CR, BCC_A20FE, BCC_A20NI, BCC_A21VA]
# [FCC_A10CR, FCC_A10FE, FCC_A10NI, FCC_A11VA]
# CPU times: user 7.14 s, sys: 26 ms, total: 7.17 s
# Wall time: 7.16 s

# %%
sys_df
# Out:
#                 GM   Phase    T     X(CR)     X(FE)     X(NI)  Y(BCC_A2,0,CR)  \
# 0     -7583.770203  BCC_A2  400  0.328560  0.375474  0.295966        0.328560
# 1     -4724.674526  BCC_A2  400  0.582552  0.383246  0.034201        0.582552
# 2     -7621.989110  BCC_A2  400  0.303014  0.464660  0.232326        0.303014
# 3     -7664.335311  BCC_A2  400  0.298539  0.455525  0.245936        0.298539
# 4     -6719.537284  BCC_A2  400  0.456458  0.224740  0.318802        0.456458
# 5     -7577.117883  BCC_A2  400  0.266374  0.572268  0.161358        0.266374
# 6     -5248.720368  BCC_A2  400  0.522918  0.435115  0.041967        0.522918
# 7     -7685.991246  BCC_A2  400  0.203244  0.338783  0.457974        0.203244
# 8     -7200.946905  BCC_A2  400  0.280475  0.172277  0.547249        0.280475
# 9     -7562.953260  BCC_A2  400  0.139415  0.781477  0.079109        0.139415
# 10    -6279.448286  BCC_A2  400  0.445178  0.067159  0.487663        0.445178
# 11    -2796.785868  BCC_A2  400  0.946980  0.019115  0.033905        0.946980
# 12    -5756.676129  BCC_A2  400  0.552654  0.226165  0.221180        0.552654
# 13    -7460.191259  BCC_A2  400  0.346983  0.278244  0.374773        0.346983
# 14    -3571.797801  BCC_A2  400  0.767147  0.167758  0.065095        0.767147
# 15    -6790.256507  BCC_A2  400  0.365134  0.534897  0.099969        0.365134
# 16    -7555.823806  BCC_A2  400  0.018807  0.790341  0.190853        0.018807
# 17    -7831.098669  BCC_A2  400  0.088074  0.742853  0.169073        0.088074
# 18    -7927.233846  BCC_A2  400  0.218652  0.498377  0.282970        0.218652
# 19    -6176.207236  BCC_A2  400  0.370394  0.027695  0.601911        0.370394
# 20    -7829.711079  BCC_A2  400  0.214122  0.590793  0.195085        0.214122
# 21    -7841.137464  BCC_A2  400  0.117213  0.725818  0.156969        0.117213
# 22    -6936.385605  BCC_A2  400  0.423347  0.201334  0.375319        0.423347
# 23    -5830.861318  BCC_A2  400  0.018903  0.343006  0.638091        0.018903
# 24    -7596.144763  BCC_A2  400  0.313977  0.294009  0.392014        0.313977
# 25    -5724.947578  BCC_A2  400  0.555222  0.228450  0.216328        0.555222
# 26    -7597.925473  BCC_A2  400  0.326706  0.361497  0.311796        0.326706
# 27    -5269.008694  BCC_A2  400  0.473903  0.515423  0.010674        0.473903
# 28    -5550.512996  BCC_A2  400  0.566612  0.127755  0.305633        0.566612
# 29    -7071.663084  BCC_A2  400  0.399421  0.377188  0.223391        0.399421
# ...            ...     ...  ...       ...       ...       ...             ...
# 19970          NaN  FCC_A1  400  0.268373  0.682265  0.049361             NaN
# 19971 -9205.023168  FCC_A1  400  0.049403  0.294376  0.656221             NaN
# 19972 -7507.850274  FCC_A1  400  0.275777  0.227892  0.496331             NaN
# 19973 -9986.549564  FCC_A1  400  0.020763  0.261762  0.717475             NaN
# 19974          NaN  FCC_A1  400  0.487459  0.181688  0.330853             NaN
# 19975          NaN  FCC_A1  400  0.561074  0.203209  0.235717             NaN
# 19976 -7225.911370  FCC_A1  400  0.101929  0.688170  0.209901             NaN
# 19977          NaN  FCC_A1  400  0.517720  0.415715  0.066565             NaN
# 19978          NaN  FCC_A1  400  0.878011  0.078134  0.043854             NaN
# 19979 -8014.121736  FCC_A1  400  0.154757  0.095505  0.749738             NaN
# 19980 -8048.914931  FCC_A1  400  0.131297  0.120856  0.747847             NaN
# 19981 -7707.867492  FCC_A1  400  0.132974  0.018688  0.848339             NaN
# 19982 -7408.693945  FCC_A1  400  0.224684  0.465691  0.309625             NaN
# 19983          NaN  FCC_A1  400  0.008627  0.951877  0.039496             NaN
# 19984 -7363.230868  FCC_A1  400  0.227880  0.469665  0.302455             NaN
# 19985          NaN  FCC_A1  400  0.550811  0.015009  0.434180             NaN
# 19986 -9222.978828  FCC_A1  400  0.013713  0.144918  0.841369             NaN
# 19987 -7570.839078  FCC_A1  400  0.111294  0.631629  0.257077             NaN
# 19988          NaN  FCC_A1  400  0.238512  0.656197  0.105291             NaN
# 19989 -7537.211977  FCC_A1  400  0.239189  0.383666  0.377145             NaN
# 19990          NaN  FCC_A1  400  0.004305  0.959266  0.036430             NaN
# 19991 -7769.732513  FCC_A1  400  0.224984  0.316557  0.458459             NaN
# 19992          NaN  FCC_A1  400  0.521576  0.198272  0.280152             NaN
# 19993          NaN  FCC_A1  400  0.353641  0.493416  0.152943             NaN
# 19994 -8750.593051  FCC_A1  400  0.071376  0.428193  0.500431             NaN
# 19995 -8613.551548  FCC_A1  400  0.078182  0.437894  0.483923             NaN
# 19996 -6041.330501  FCC_A1  400  0.435471  0.223709  0.340820             NaN
# 19997 -7348.707036  FCC_A1  400  0.317692  0.040264  0.642044             NaN
# 19998          NaN  FCC_A1  400  0.523257  0.425222  0.051521             NaN
# 19999 -8217.344996  FCC_A1  400  0.088922  0.536841  0.374237             NaN
#
#        Y(BCC_A2,0,FE)  Y(BCC_A2,0,NI)  Y(BCC_A2,1,VA)  Y(FCC_A1,0,CR)  \
# 0            0.375474        0.295966               1             NaN
# 1            0.383246        0.034201               1             NaN
# 2            0.464660        0.232326               1             NaN
# 3            0.455525        0.245936               1             NaN
# 4            0.224740        0.318802               1             NaN
# 5            0.572268        0.161358               1             NaN
# 6            0.435115        0.041967               1             NaN
# 7            0.338783        0.457974               1             NaN
# 8            0.172277        0.547249               1             NaN
# 9            0.781477        0.079109               1             NaN
# 10           0.067159        0.487663               1             NaN
# 11           0.019115        0.033905               1             NaN
# 12           0.226165        0.221180               1             NaN
# 13           0.278244        0.374773               1             NaN
# 14           0.167758        0.065095               1             NaN
# 15           0.534897        0.099969               1             NaN
# 16           0.790341        0.190853               1             NaN
# 17           0.742853        0.169073               1             NaN
# 18           0.498377        0.282970               1             NaN
# 19           0.027695        0.601911               1             NaN
# 20           0.590793        0.195085               1             NaN
# 21           0.725818        0.156969               1             NaN
# 22           0.201334        0.375319               1             NaN
# 23           0.343006        0.638091               1             NaN
# 19987        0.631629        0.257077               1
# 19988        0.656197        0.105291               1
# 19989        0.383666        0.377145               1
# 19990        0.959266        0.036430               1
# 19991        0.316557        0.458459               1
# 19992        0.198272        0.280152               1
# 19993        0.493416        0.152943               1
# 19994        0.428193        0.500431               1
# 19995        0.437894        0.483923               1
# 19996        0.223709        0.340820               1
# 19997        0.040264        0.642044               1
# 19998        0.425222        0.051521               1
# 19999        0.536841        0.374237               1
#
# [20000 rows x 14 columns]

# %%
# Perform some setup for phase-specific coloring of points
import numpy as np
colorlist = {}

# colors from Junwei Huang, March 21 2013
ColorValues=["FF0000", "00FF00", "0000FF", "FFFF00", "FF00FF", "00FFFF", "000000", 
        "800000", "008000", "000080", "808000", "800080", "008080", "808080", 
        "C00000", "00C000", "0000C0", "C0C000", "C000C0", "00C0C0", "C0C0C0", 
        "400000", "004000", "000040", "404000", "400040", "004040", "404040", 
        "200000", "002000", "000020", "202000", "200020", "002020", "202020", 
        "600000", "006000", "000060", "606000", "600060", "006060", "606060", 
        "A00000", "00A000", "0000A0", "A0A000", "A000A0", "00A0A0", "A0A0A0", 
        "E00000", "00E000", "0000E0", "E0E000", "E000E0", "00E0E0", "E0E0E0"]
M=len(ColorValues)

phasecount = 0
for phase in ['BCC_A2','FCC_A1','SIGMA']:
	colorlist[phase] = "#"+ColorValues[np.mod(phasecount,M)]
	phasecount = phasecount + 1

# Get the configured plot colors
plotcolors = list(map(lambda x: colorlist[x], sys_df['Phase'].values))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import scipy.spatial
fig = plt.figure(dpi=600,figsize=(12,12))
ax = fig.gca(projection="triangular") # use ternary axes
ax.tick_params(axis='both', which='major', labelsize=14)
ax.grid(False)
plt.xlim([-0.01,1])
plt.ylim([-0.01,1])
plt.gca().set_aspect('equal')
hull = scipy.spatial.ConvexHull(
    sys_df[['X(NI)', 'X(CR)', 'GM']].values
)
ax.triplot(sys_df['X(NI)'].values, sys_df['X(CR)'].values, hull.simplices, 'go-', marker=None, zorder=1)
plt.show()

# %%
# Final plotting setup
import numpy as np
import matplotlib.pyplot as plt
import scipy.spatial
x_variable = 'X(CR)'
y_variable = 'X(NI)'
x = sys_df[x_variable]
y = sys_df[y_variable]
triangles = np.asarray(hull.simplices)

fig = plt.figure(dpi=600,figsize=(9,9))
ax = fig.gca(projection="triangular") # use ternary axes
ax.tick_params(axis='both', which='major', labelsize=14)
ax.grid(True)
plt.xlim([-0.01,1])
plt.ylim([-0.01,1])
plt.gca().set_aspect('equal')
plt.triplot(x, y, triangles, 'go-', color='k', marker=None, zorder=1)

ax.text(0.3, 0.8, 'T = '+str(sys_df['T'][0])+ ' K',
        verticalalignment='bottom', horizontalalignment='left',
        color='black', fontsize=20)

for phase in ['BCC_A2', 'FCC_A1']:
    # Plot each phase separately so we can mark the legend properly
    phase_frame = sys_df[(sys_df.Phase == phase)]
    if (len(phase_frame) > 0):
        ax.scatter(phase_frame[x_variable], phase_frame[y_variable], c=colorlist[phase],
                       marker='o',
                       label=phase,
                       zorder=2)
        ax.legend(loc=0, fontsize=15)
plt.title('Using DataFrames',fontsize=25, x=0.5, y=0.9)
ax.set_xlabel(x_variable, labelpad=15,fontsize=20)
ax.set_ylabel(y_variable,rotation=60,fontsize=20,labelpad=-120)
plt.show()
