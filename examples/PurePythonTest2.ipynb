# %%
# %matplotlib inline
from pycalphad.io.tdb import tdbread
from pycalphad import Database, eq, isotherm
from pycalphad.variables import *

db = Database()
tdbread(db, open('bigrose.tdb').read())
# %time sys_df = eq(db, ['H', 'HE', 'LI'] , ['TEST'], T=1200)
# Out:
# [y^{TEST}_{0},_{HE}, y^{TEST}_{0},_{LI}, y^{TEST}_{0},_{H}]
# CPU times: user 14.3 s, sys: 199 ms, total: 14.5 s
# Wall time: 14.9 s
# /home/rotis/.virtualenvs/calphad/lib/python3.3/site-packages/matplotlib/__init__.py:1039: UserWarning: Bad val "pyside" on line #38
# 	"backend      : pyside
# "
# 	in file "/home/rotis/.virtualenvs/calphad/lib/python3.3/site-packages/matplotlib/mpl-data/matplotlibrc"
# 	Key backend: Unrecognized backend string "pyside": valid strings are ['GTK3Agg', 'Qt4Agg', 'agg', 'GTK', 'GTKCairo', 'cairo', 'pgf', 'emf', 'ps', 'WebAgg', 'gdk', 'template', 'TkAgg', 'Qt5Agg', 'CocoaAgg', 'WXAgg', 'GTK3Cairo', 'WX', 'svg', 'pdf', 'GTKAgg', 'nbAgg', 'MacOSX']
#   (val, error_details, msg))

# %%
# %time isotherm(sys_df, 'X(H)','X(HE)', T=1200)
# Out:
# CPU times: user 4.88 s, sys: 55 ms, total: 4.94 s
# Wall time: 4.93 s
