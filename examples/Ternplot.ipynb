# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import calphad.plot.projections.triangular
from matplotlib.patches import Polygon

ax = plt.subplot(111, projection="triangular")
p = plt.plot([0.4, 0.2], [0.3, 0.8])
poly = Polygon([[0,0],[1,0],[0,1]])
#plt.gca().add_patch(poly)
plt.grid(True)

plt.show()
