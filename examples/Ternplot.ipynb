# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import calphad.plot.projections.triangular
from matplotlib.patches import Polygon

plt.subplot(111, projection="triangular")
p = plt.plot([0.4, 0.2], [0.3, 0.8])
poly = Polygon([[0,0],[1,0],[0,1]])
#plt.gca().add_patch(poly)
plt.grid(True)

plt.show()

# %%
import numpy as np
len(np.linspace(1, 10, 1, True))
# Out:
# 1
