# %%
# %matplotlib inline
from pycalphad import Database, binplot, energy_surf

db = Database('alfe_fries.tdb')
my_phases = ['LIQUID', 'FCC_A1', 'BCC_NOB', 'AL8FE5_D82', 'AL5FE2', 'AL2FE', 'AL13FE4']
# %time binplot(db, ['AL', 'FE', 'VA'] , my_phases, 'X(AL)', 300, 2000, points_per_phase=2000, steps=100, ast='numpy')
# Out:
# CPU times: user 59 s, sys: 132 ms, total: 59.1 s
# Wall time: 59.1 s
