# %%
# %matplotlib inline
from pycalphad import Database, binplot

db = Database('alfe_fries.tdb')
my_phases = ['LIQUID', 'FCC_A1', 'BCC_NOB', 'AL8FE5_D82', 'AL5FE2', 'AL2FE', 'AL13FE4']
# %time binplot(db, ['AL', 'FE', 'VA'] , my_phases, 'X(AL)', 300, 2000, points_per_phase=5000, steps=100, ast='numpy')
# Out:
# CPU times: user 6min 35s, sys: 1min 46s, total: 8min 21s
# Wall time: 8min 21s
