# %%
# %matplotlib inline
from pycalphad import Database, binplot

db = Database('alfe_fries.tdb')
my_phases = ['LIQUID', 'FCC_A1', 'BCC_NOB', 'AL8FE5_D82', 'AL5FE2', 'AL2FE', 'AL13FE4']
# %time binplot(db, ['AL', 'FE', 'VA'] , my_phases, 'X(AL)', 300, 2000, points_per_phase=2000, steps=100)
# Out:
# CPU times: user 40.5 s, sys: 244 ms, total: 40.8 s
# Wall time: 40.7 s
