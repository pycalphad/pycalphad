# %%
# %matplotlib inline
from pycalphad import Database, binplot

db = Database('alfe_sei.TDB')
my_phases = ['LIQUID', 'BCC_A2', 'B2_BCC', 'FCC_A1', 'HCP_A3', 'AL5FE2', 'AL2FE', 'AL13FE4', 'AL5FE4']
# %time binplot(db, ['AL', 'FE', 'VA'] , my_phases, 'X(AL)', 300, 2000, steps=100, points_per_phase=1000, ast='numpy')
# Out:
# CPU times: user 13.6 s, sys: 179 ms, total: 13.8 s
# Wall time: 13.8 s
