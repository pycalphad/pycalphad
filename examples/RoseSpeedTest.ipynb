# %%
import timeit

comps = ['H', 'HE', 'LI', 'BE', 'B', 'C', 'N', 'O', 'F', 'NE']
nums = []
times = []
for c in range(len(comps)+1)[2:]:
    setup_code = """
from pycalphad import Database, energy_surf
from pycalphad.variables import T
db = Database('bigrose.tdb')
my_phases = ['TEST']
comps = """ + str(comps[:c])
    test_code = "energy_surf(db, comps, my_phases, T=1273, points_per_phase=200000, ast='numpy')"
    nums.append(c)
    times.append(timeit.timeit(test_code, setup=setup_code, number=1))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(nums, times)
plt.xlabel('Number of Components')
plt.ylabel('Time (sec)')
plt.show()

# %%
import timeit
comps = ['H', 'HE', 'LI', 'BE', 'B', 'C', 'N', 'O', 'F', 'NE']
nums = []
times = []
for c in range(len(comps)+1)[2:]:
    setup_code = """
from pycalphad import Database, energy_surf
from pycalphad.variables import T
db = Database('bigrose.tdb')
my_phases = ['TEST']
comps = """ + str(comps[:c])
    test_code = "energy_surf(db, comps, my_phases, T=1273, points_per_phase=200000, ast='numexpr')"
    nums.append(c)
    times.append(timeit.timeit(test_code, setup=setup_code, number=1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-8e5a6cbedc3d> in <module>()
#      12     test_code = "energy_surf(db, comps, my_phases, T=1273, points_per_phase=200000, ast='numexpr')"
#      13     nums.append(c)
# ---> 14     times.append(timeit.timeit(test_code, setup=setup_code, number=1))
#
# /usr/lib64/python3.3/timeit.py in timeit(stmt, setup, timer, number)
#     223            number=default_number):
#     224     """Convenience function to create Timer object and call timeit method."""
# --> 225     return Timer(stmt, setup, timer).timeit(number)
#     226
#     227 def repeat(stmt="pass", setup="pass", timer=default_timer,
#
# /usr/lib64/python3.3/timeit.py in timeit(self, number)
#     188         gc.disable()
#     189         try:
# --> 190             timing = self.inner(it, self.timer)
#     191         finally:
#     192             if gcold:
#
# /usr/lib64/python3.3/timeit.py in inner(_it, _timer)
#
# /home/rotis/.virtualenvs/calphad/lib/python3.3/site-packages/pycalphad-0.0.1-py3.3.egg/pycalphad/eq/energy_surf.py in energy_surf(db, comps, phases, points_per_phase, ast, **kwargs)
#     123                 (np.repeat(list(statevars.values()), len(points)), points)
#     124             )
# --> 125             energies = comp_sets[phase_name](*inputs.T)
#     126
#     127             # Add points and calculated energies to the DataFrame
#
# /home/rotis/.virtualenvs/calphad/lib/python3.3/site-packages/numexpr-2.4.1.dev0-py3.3-linux-x86_64.egg/numexpr/__init__.py in <lambda>(_Dummy_179, _Dummy_180, _Dummy_181, _Dummy_182, _Dummy_183, _Dummy_184, _Dummy_185, _Dummy_186)
#
# /home/rotis/.virtualenvs/calphad/lib/python3.3/site-packages/numexpr-2.4.1.dev0-py3.3-linux-x86_64.egg/numexpr/necompiler.py in evaluate(ex, local_dict, global_dict, out, order, casting, **kwargs)
#     762     except KeyError:
#     763         compiled_ex = _numexpr_cache[numexpr_key] = \
# --> 764             NumExpr(ex, signature, **context)
#     765     kwargs = {'out': out, 'order': order, 'casting': casting,
#     766               'ex_uses_vml': ex_uses_vml}
#
# /home/rotis/.virtualenvs/calphad/lib/python3.3/site-packages/numexpr-2.4.1.dev0-py3.3-linux-x86_64.egg/numexpr/necompiler.py in NumExpr(ex, signature, **kwargs)
#     576     threeAddrProgram, inputsig, tempsig, constants, input_names = \
#     577         precompile(ex, signature, context)
# --> 578     program = compileThreeAddrForm(threeAddrProgram)
#     579     return interpreter.NumExpr(inputsig.encode('ascii'),
#     580                                tempsig.encode('ascii'),
#
# /home/rotis/.virtualenvs/calphad/lib/python3.3/site-packages/numexpr-2.4.1.dev0-py3.3-linux-x86_64.egg/numexpr/necompiler.py in compileThreeAddrForm(program)
#     472         return b''.join(l)
#     473
# --> 474     prog_str = b''.join([toString(t) for t in program])
#     475     return prog_str
#     476
#
# /home/rotis/.virtualenvs/calphad/lib/python3.3/site-packages/numexpr-2.4.1.dev0-py3.3-linux-x86_64.egg/numexpr/necompiler.py in <listcomp>(.0)
#     472         return b''.join(l)
#     473
# --> 474     prog_str = b''.join([toString(t) for t in program])
#     475     return prog_str
#     476
#
# /home/rotis/.virtualenvs/calphad/lib/python3.3/site-packages/numexpr-2.4.1.dev0-py3.3-linux-x86_64.egg/numexpr/necompiler.py in toString(args)
#     463             args += (None,)
#     464         opcode, store, a1, a2 = args[:4]
# --> 465         s = quadrupleToString(opcode, store, a1, a2)
#     466         l = [s]
#     467         args = args[4:]
#
# /home/rotis/.virtualenvs/calphad/lib/python3.3/site-packages/numexpr-2.4.1.dev0-py3.3-linux-x86_64.egg/numexpr/necompiler.py in quadrupleToString(opcode, store, a1, a2)
#     454     def quadrupleToString(opcode, store, a1=None, a2=None):
#     455         cop = chr(interpreter.opcodes[opcode]).encode('ascii')
# --> 456         cs = nToChr(store)
#     457         ca1 = nToChr(a1)
#     458         ca2 = nToChr(a2)
#
# /home/rotis/.virtualenvs/calphad/lib/python3.3/site-packages/numexpr-2.4.1.dev0-py3.3-linux-x86_64.egg/numexpr/necompiler.py in nToChr(reg)
#     450                 # int.to_bytes is not available in Python < 3.2
#     451                 #return reg.n.to_bytes(1, sys.byteorder)
# --> 452                 return bytes([reg.n])
#     453
#     454     def quadrupleToString(opcode, store, a1=None, a2=None):
#
# ValueError: bytes must be in range(0, 256)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(nums, times)
plt.xlabel('Number of Components')
plt.ylabel('Time (sec)')
plt.show()
