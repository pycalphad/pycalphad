# %%
# %matplotlib inline
from pycalphad import Database, Equilibrium, energy_surf
from pycalphad.variables import *

db = Database('alzn_mey.tdb')
my_phases = ['FCC_A1', 'HCP_A3', 'LIQUID']
comps = ['AL', 'ZN', 'VA']
comp_dict = {X('ZN'): 0.2}
# %time energy_surf(db, comps, my_phases, T=500, points_per_phase=2000, ast='numpy')
# Out:
# CPU times: user 489 ms, sys: 1 ms, total: 490 ms
# Wall time: 490 ms
#                 GM   Phase    T     X(AL)     X(ZN)  Y(FCC_A1,0,AL)  \
# 0    -20530.211590  FCC_A1  500  0.211297  0.788703        0.211297
# 1    -17548.507730  FCC_A1  500  0.706443  0.293557        0.706443
# 2    -19938.303973  FCC_A1  500  0.330799  0.669201        0.330799
# 3    -17017.992479  FCC_A1  500  0.803151  0.196849        0.803151
# 4    -15815.492866  FCC_A1  500  0.986014  0.013986        0.986014
# 5    -18703.533459  FCC_A1  500  0.520855  0.479145        0.520855
# 6    -20458.695084  FCC_A1  500  0.029789  0.970211        0.029789
# 7    -18282.740860  FCC_A1  500  0.585340  0.414660        0.585340
# 8    -18541.719987  FCC_A1  500  0.545384  0.454616        0.545384
# 9    -20388.700547  FCC_A1  500  0.245756  0.754244        0.245756
# 10   -16731.083684  FCC_A1  500  0.856684  0.143316        0.856684
# 11   -18964.212239  FCC_A1  500  0.481736  0.518264        0.481736
# ...
