# %%
from calphad.io.database import Database
from calphad.io.tdb import tdbread
from calphad.model import Model, Y

db = Database()
tdbread(db, open('crfeni_mie.tdb').read())
mod = Model(db, ['FE','CR','NI'], ['LIQUID'])
# Out:
# Adding LIQUID with [1.0]
# Adding BCC_A2 with [1.0, 3.0]
# Adding FCC_A1 with [1.0, 1.0]
# Adding HCP_A3 with [1.0, 0.5]
# Adding SIGMA with [8.0, 4.0, 18.0]
# Initializing model for ['LIQUID']
# Checking BCC_A2
# Checking LIQUID
# Found parameters: [{'phase_name': 'LIQUID', 'parameter': Piecewise((GLIQCR, And(T < 6000.0, T >= 300.0))), 'reference': None, 'parameter_order': 0, 'constituent_array': [['CR']], 'parameter_type': 'G'}, {'phase_name': 'LIQUID', 'parameter': Piecewise((GLIQFE, And(T < 6000.0, T >= 300.0))), 'parameter_type': 'G', 'parameter_order': 0, 'constituent_array': [['FE']], 'reference': None}, {'phase_name': 'LIQUID', 'parameter': Piecewise((GLIQNI, And(T < 6000.0, T >= 300.0))), 'reference': None, 'parameter_order': 0, 'constituent_array': [['NI']], 'parameter_type': 'G'}]
# Checking SIGMA
# Checking HCP_A3
# Checking FCC_A1
# Initialization complete

# %%
from sympy.interactive import printing
printing.init_printing(use_latex=True)

# %%
mod()
# Out:
#                 ⎛⎧⎧             7               3               2
#                 ⎜⎪⎪2.37615e-21⋅T  - 1.47721e-6⋅T  + 0.00189435⋅T  - 26.908⋅T⋅l
# Y_0,_CR__LIQUID⋅⎜⎨⎨
#                 ⎜⎪⎪
#                 ⎝⎩⎩                              -50⋅T⋅log(T) + 335.616316⋅T -
#
#                                    139250
# og(T) + 146.059775⋅T + 15483.015 + ──────  for T ≥ 300.0 ∧ T < 2180.0
#                                      T                                  for T
#
#  16459.984                                 for T ≥ 2180.0 ∧ T < 6000.0
#
#                     ⎞                   ⎛⎧⎧               7              3
#                     ⎟                   ⎜⎪⎪- 3.67516e-21⋅T  - 5.8927e-8⋅T  - 0
# ≥ 300.0 ∧ T < 6000.0⎟ + Y_0,_FE__LIQUID⋅⎜⎨⎨
#                     ⎟                   ⎜⎪⎪
#                     ⎠                   ⎝⎩⎩                                -46
#
#            2                                               77359
# .00439752⋅T  - 23.5143⋅T⋅log(T) + 117.57557⋅T + 13265.87 + ─────  for T ≥ 300.
#                                                              T
#
# ⋅T⋅log(T) + 291.302⋅T - 10838.83                                  for T ≥ 1811
#
#                                            ⎞                   ⎛⎧⎧
# 0 ∧ T < 1811.0                             ⎟                   ⎜⎪⎪- 3.82318e-2
#                  for T ≥ 300.0 ∧ T < 6000.0⎟ + Y_0,_NI__LIQUID⋅⎜⎨⎨
#                                            ⎟                   ⎜⎪⎪
# .0 ∧ T < 6000.0                            ⎠                   ⎝⎩⎩
#
#    7              2
# 1⋅T  - 0.0048407⋅T  - 22.096⋅T⋅log(T) + 108.457⋅T + 11235.527  for T ≥ 300.0 ∧
#
#       -43.1⋅T⋅log(T) + 268.598⋅T - 9549.775                    for T ≥ 1728.0
#
#
#                                         ⎞
#  T < 1728.0                             ⎟
#               for T ≥ 300.0 ∧ T < 6000.0⎟
# ∧ T < 3000.0                            ⎟
#                                         ⎠

# %%
mod({'T':2181})
# Out:
# Y_0,_CR__LIQUID⋅(-109050⋅log(2181) + 715519.201196) + Y_0,_FE__LIQUID⋅(-100326
# ⋅log(2181) + 624490.832) + Y_0,_NI__LIQUID⋅(-94001.1⋅log(2181) + 576262.463)

# %%
mod({'T':300,Y('LIQUID',0,'CR'):0.33, Y('LIQUID',0,'FE'):0.33, Y('LIQUID',0,'NI'):0.34})
# Out:
# -7245.5997⋅log(300) + 50471.8373572951

# %%
mod({'T':300,Y('LIQUID',0,'CR'):0.33, Y('LIQUID',0,'FE'):0.33, Y('LIQUID',0,'NI'):0.34}).evalf()
# Out:
# 9144.51277006090

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from numpy import linspace
x = []
y = []
temp = 300 # Kelvin
for t in linspace(0,0.7):
    ni_content = 0.3
    fe_content = t
    cr_content = 1.0 - fe_content - ni_content
    x.append(fe_content)
    y.append(float(mod({'T':temp,Y('LIQUID',0,'CR'):cr_content, Y('LIQUID',0,'FE'):fe_content, Y('LIQUID',0,'NI'):ni_content})))
plt.plot(x, y)
plt.show()
