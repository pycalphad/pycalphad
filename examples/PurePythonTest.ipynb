# %%
from calphad.io.database import Database
from calphad.io.tdb import tdbread
from calphad.model import Model
from calphad.variables import *

db = Database()
tdbread(db, open('crfeni_mie.tdb').read())
cur_phase = 'BCC_A2'
mod = Model(db, ['FE','CR','NI','VA'], [cur_phase])
# Out:
# Adding LIQUID with [1.0]
# Adding BCC_A2 with [1.0, 3.0]
# Adding FCC_A1 with [1.0, 1.0]
# Adding HCP_A3 with [1.0, 0.5]
# Adding SIGMA with [8.0, 4.0, 18.0]
# Initializing model for ['BCC_A2']
# Checking LIQUID
# Checking BCC_A2
# Checking FCC_A1
# Checking SIGMA
# Checking HCP_A3
# Initialization complete

# %%
from sympy.interactive import printing
printing.init_printing(use_latex=True)

# %%
mod()
# Out:
#
#
#
#                                                                        ⎛38⋅y_{
# 0.25⋅y_{0},_{CR}__{BCC-A2}⋅y_{0},_{FE}__{BCC-A2}⋅y_{0},_{NI}__{BCC-A2}⋅⎜──────
#                                                                        ⎝
#
#
#
#
#
#
#
# 0},_{CR}__{BCC-A2}   16⋅y_{0},_{FE}__{BCC-A2}   16⋅y_{0},_{NI}__{BCC-A2}   11⎞
# ────────────────── - ──────────────────────── - ──────────────────────── - ──⎟
#      27                         27                         27              27⎠
#
#
#
#
#
#
# 2
#
#  ⋅({10⋅T - 27000  for T ≥ 300.0 ∧ T < 6000.0) + 0.25⋅y_{0},_{CR}__{BCC-A2}⋅y_{
#
#
#
#
#
#
#
#
#                                          ⎛38⋅y_{0},_{CR}__{BCC-A2}   16⋅y_{0},
# 0},_{FE}__{BCC-A2}⋅y_{0},_{NI}__{BCC-A2}⋅⎜──────────────────────── - ─────────
#                                          ⎝           27
#
#
#
#
#
#
#
# _{FE}__{BCC-A2}   16⋅y_{0},_{NI}__{BCC-A2}   11⎞
# ─────────────── - ──────────────────────── - ──⎟⋅({10⋅T - 18500  for T ≥ 300.0
# ...

# %%
mod({T:2181})
# Out:
#
#                                                                            ⎛38
# - 1297.5⋅y_{0},_{CR}__{BCC-A2}⋅y_{0},_{FE}__{BCC-A2}⋅y_{0},_{NI}__{BCC-A2}⋅⎜──
#                                                                            ⎝
#
#
# ⋅y_{0},_{CR}__{BCC-A2}   16⋅y_{0},_{FE}__{BCC-A2}   16⋅y_{0},_{NI}__{BCC-A2}
# ────────────────────── - ──────────────────────── - ──────────────────────── -
#          27                         27                         27
#
#     2
#  11⎞
#  ──⎟  + 827.5⋅y_{0},_{CR}__{BCC-A2}⋅y_{0},_{FE}__{BCC-A2}⋅y_{0},_{NI}__{BCC-A2
#  27⎠
#
#
#   ⎛38⋅y_{0},_{CR}__{BCC-A2}   16⋅y_{0},_{FE}__{BCC-A2}   16⋅y_{0},_{NI}__{BCC-
# }⋅⎜──────────────────────── - ──────────────────────── - ─────────────────────
#   ⎝           27                         27                         27
#
#
# A2}   11⎞
# ─── - ──⎟ + 6952.5⋅y_{0},_{CR}__{BCC-A2}⋅y_{0},_{FE}__{BCC-A2}⋅y_{0},_{NI}__{B
#       27⎠
#
#
#
# ...

# %%
mod({T:300,Y(cur_phase,0,'CR'):0.33, Y(cur_phase,0,'FE'):0.33, Y(cur_phase,0,'NI'):0.34,Y(cur_phase,1,'VA'):1})
# Out:
# -1811.399925⋅log(300) + 37774.3606187689

# %%
mod({T:300,Y(cur_phase,0,'CR'):0.33, Y(cur_phase,0,'FE'):0.33, Y(cur_phase,0,'NI'):0.34,Y(cur_phase,1,'VA'):1}).evalf()
# Out:
# 27442.5294719604

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from numpy import linspace
x = []
y = []
temp = 1000 # Kelvin
for t in linspace(0,0.7):
    ni_content = 0.3
    fe_content = t
    cr_content = 1.0 - fe_content - ni_content
    x.append(fe_content)
    y.append(float(mod({T:300,Y(cur_phase,0,'CR'):0.33, Y(cur_phase,0,'FE'):0.33, Y(cur_phase,0,'NI'):0.34,Y(cur_phase,1,'VA'):1})))
plt.plot(x, y)
plt.show()
