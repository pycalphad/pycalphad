# %%
from calphad.io.database import Database
from calphad.io.tdb import tdbread
from calphad.model import Model, Y

db = Database()
tdbread(db, open('crfeni_mie.tdb').read())
mod = Model(db, ['FE','CR','NI'], ['LIQUID'])
# Out:
# Adding LIQUID with [1.0]
# Adding BCC_A2 with [1.0, 3.0]
# Adding FCC_A1 with [1.0, 1.0]
# Adding HCP_A3 with [1.0, 0.5]
# Adding SIGMA with [8.0, 4.0, 18.0]
# Initializing model for ['LIQUID']
# Checking BCC_A2
# Checking SIGMA
# Checking LIQUID
# Checking HCP_A3
# Checking FCC_A1
# Initialization complete

# %%
from sympy.interactive import printing
printing.init_printing(use_latex=True)

# %%
mod()
# Out:
#
#
# 8.3145⋅T⋅Y_0,_CR__LIQUID⋅log(Y_0,_CR__LIQUID) + 8.3145⋅T⋅Y_0,_FE__LIQUID⋅log(Y
#
#
#
#
#
# _0,_FE__LIQUID) + 8.3145⋅T⋅Y_0,_NI__LIQUID⋅log(Y_0,_NI__LIQUID) + 1.0⋅Y_0,_CR_
#
#
#
#
#                                         ⎛  26⋅Y_0,_CR__LIQUID   26⋅Y_0,_FE__LI
# _LIQUID⋅Y_0,_FE__LIQUID⋅Y_0,_NI__LIQUID⋅⎜- ────────────────── - ──────────────
#                                         ⎝          27                   27
#
#
#                                2
# QUID   28⋅Y_0,_NI__LIQUID   1 ⎞
# ──── + ────────────────── - ──⎟ ⋅({-50⋅T + 60000  for T ≥ 300.0 ∧ T < 6000.0)
#                27           27⎠
#
#
#
#                                                       ⎛  26⋅Y_0,_CR__LIQUID
# + 1.0⋅Y_0,_CR__LIQUID⋅Y_0,_FE__LIQUID⋅Y_0,_NI__LIQUID⋅⎜- ────────────────── -
#                                                       ⎝          27
#
#
#
# 26⋅Y_0,_FE__LIQUID   28⋅Y_0,_NI__LIQUID   1 ⎞
# ────────────────── + ────────────────── - ──⎟⋅({-50⋅T + 80000  for T ≥ 300.0 ∧
#         27                   27           27⎠
#
#
#
#
#  T < 6000.0) + 1.0⋅Y_0,_CR__LIQUID⋅Y_0,_FE__LIQUID⋅Y_0,_NI__LIQUID⋅({-50⋅T + 1
#
#
#
#
#                                                                          ⎛5⋅Y_
# 30000  for T ≥ 300.0 ∧ T < 6000.0) + 1.0⋅Y_0,_CR__LIQUID⋅Y_0,_FE__LIQUID⋅⎜────
#                                                                          ⎝
#
#
#
# 0,_CR__LIQUID   3⋅Y_0,_FE__LIQUID   1⎞
# ───────────── - ───────────────── - ─⎟⋅({-1331  for T ≥ 300.0 ∧ T < 6000.0) +
#     4                   4           4⎠
#
#
#
#
# 1.0⋅Y_0,_CR__LIQUID⋅Y_0,_FE__LIQUID⋅({7.996546⋅T - 17737  for T ≥ 300.0 ∧ T <
#
#
#
#
#                                               ⎛  5⋅Y_0,_CR__LIQUID   3⋅Y_0,_NI
# 6000.0) + 1.0⋅Y_0,_CR__LIQUID⋅Y_0,_NI__LIQUID⋅⎜- ───────────────── + ─────────
#                                               ⎝          4                   4
#
#
#
# __LIQUID   1⎞
# ──────── + ─⎟⋅({-6.3696⋅T + 16941  for T ≥ 300.0 ∧ T < 6000.0) + 1.0⋅Y_0,_CR__
#            4⎠
#
#
#
#
# LIQUID⋅Y_0,_NI__LIQUID⋅({-7.3318⋅T + 318  for T ≥ 300.0 ∧ T < 6000.0) + 1.0⋅Y_
#
#
#
#               ⎛⎧⎧             7               3               2
#               ⎜⎪⎪2.37615e-21⋅T  - 1.47721e-6⋅T  + 0.00189435⋅T  - 26.908⋅T⋅log
# 0,_CR__LIQUID⋅⎜⎨⎨
#               ⎜⎪⎪
#               ⎝⎩⎩                              -50⋅T⋅log(T) + 335.616316⋅T - 1
#
#                                  139250
# (T) + 146.059775⋅T + 15483.015 + ──────  for T ≥ 300.0 ∧ T < 2180.0
#                                    T                                  for T ≥
#
# 6459.984                                 for T ≥ 2180.0 ∧ T < 6000.0
#
#                   ⎞
#                   ⎟                                       ⎛  5⋅Y_0,_FE__LIQUID
# 300.0 ∧ T < 6000.0⎟ + 1.0⋅Y_0,_FE__LIQUID⋅Y_0,_NI__LIQUID⋅⎜- ─────────────────
#                   ⎟                                       ⎝          4
#                   ⎠
#
#
#    3⋅Y_0,_NI__LIQUID   1⎞
#  + ───────────────── + ─⎟⋅({-4.146656⋅T + 10180  for T ≥ 300.0 ∧ T < 6000.0) +
#            4           4⎠
#
#
#
#
#  1.0⋅Y_0,_FE__LIQUID⋅Y_0,_NI__LIQUID⋅({5.1622⋅T - 16911  for T ≥ 300.0 ∧ T < 6
#
#
#
#                              ⎛⎧⎧               7              3
#                              ⎜⎪⎪- 3.67516e-21⋅T  - 5.8927e-8⋅T  - 0.00439752⋅T
# 000.0) + 1.0⋅Y_0,_FE__LIQUID⋅⎜⎨⎨
#                              ⎜⎪⎪
#                              ⎝⎩⎩                                -46⋅T⋅log(T) +
#
# 2                                               77359
#   - 23.5143⋅T⋅log(T) + 117.57557⋅T + 13265.87 + ─────  for T ≥ 300.0 ∧ T < 181
#                                                   T
#
#  291.302⋅T - 10838.83                                  for T ≥ 1811.0 ∧ T < 60
#
#                                 ⎞                       ⎛⎧⎧               7
# 1.0                             ⎟                       ⎜⎪⎪- 3.82318e-21⋅T  -
#       for T ≥ 300.0 ∧ T < 6000.0⎟ + 1.0⋅Y_0,_NI__LIQUID⋅⎜⎨⎨
#                                 ⎟                       ⎜⎪⎪                  -
# 00.0                            ⎠                       ⎝⎩⎩
#
#            2
# 0.0048407⋅T  - 22.096⋅T⋅log(T) + 108.457⋅T + 11235.527  for T ≥ 300.0 ∧ T < 17
#
# 43.1⋅T⋅log(T) + 268.598⋅T - 9549.775                    for T ≥ 1728.0 ∧ T < 3
#
#
#                                  ⎞
# 28.0                             ⎟
#        for T ≥ 300.0 ∧ T < 6000.0⎟
# 000.0                            ⎟
#                                  ⎠

# %%
mod({'T':2181})
# Out:
#
#                                                           ⎛  26⋅Y_0,_CR__LIQUI
# - 49050.0⋅Y_0,_CR__LIQUID⋅Y_0,_FE__LIQUID⋅Y_0,_NI__LIQUID⋅⎜- ─────────────────
#                                                           ⎝          27
#
#                                                  2
# D   26⋅Y_0,_FE__LIQUID   28⋅Y_0,_NI__LIQUID   1 ⎞
# ─ - ────────────────── + ────────────────── - ──⎟  - 29050.0⋅Y_0,_CR__LIQUID⋅Y
#             27                   27           27⎠
#
#
#                                ⎛  26⋅Y_0,_CR__LIQUID   26⋅Y_0,_FE__LIQUID   28
# _0,_FE__LIQUID⋅Y_0,_NI__LIQUID⋅⎜- ────────────────── - ────────────────── + ──
#                                ⎝          27                   27
#
#
# ⋅Y_0,_NI__LIQUID   1 ⎞
# ──────────────── - ──⎟ + 20950.0⋅Y_0,_CR__LIQUID⋅Y_0,_FE__LIQUID⋅Y_0,_NI__LIQU
#       27           27⎠
#
#
#                                             ⎛5⋅Y_0,_CR__LIQUID   3⋅Y_0,_FE__LI
# ID - 1331.0⋅Y_0,_CR__LIQUID⋅Y_0,_FE__LIQUID⋅⎜───────────────── - ─────────────
#                                             ⎝        4                   4
#
#
# QUID   1⎞
# ──── - ─⎟ - 296.533174⋅Y_0,_CR__LIQUID⋅Y_0,_FE__LIQUID + 3048.9024⋅Y_0,_CR__LI
#        4⎠
#
#
#                      ⎛  5⋅Y_0,_CR__LIQUID   3⋅Y_0,_NI__LIQUID   1⎞
# QUID⋅Y_0,_NI__LIQUID⋅⎜- ───────────────── + ───────────────── + ─⎟ - 15672.655
#                      ⎝          4                   4           4⎠
#
#
#
# 8⋅Y_0,_CR__LIQUID⋅Y_0,_NI__LIQUID + 18133.9245⋅Y_0,_CR__LIQUID⋅log(Y_0,_CR__LI
#
#
#
#
# QUID) + 1.0⋅Y_0,_CR__LIQUID⋅(-109050⋅log(2181) + 715519.201196) + 1136.143264⋅
#
#
#
#                                 ⎛  5⋅Y_0,_FE__LIQUID   3⋅Y_0,_NI__LIQUID   1⎞
# Y_0,_FE__LIQUID⋅Y_0,_NI__LIQUID⋅⎜- ───────────────── + ───────────────── + ─⎟
#                                 ⎝          4                   4           4⎠
#
#
#
# - 5652.2418⋅Y_0,_FE__LIQUID⋅Y_0,_NI__LIQUID + 18133.9245⋅Y_0,_FE__LIQUID⋅log(Y
#
#
#
#
# _0,_FE__LIQUID) + 1.0⋅Y_0,_FE__LIQUID⋅(-100326⋅log(2181) + 624490.832) + 18133
#
#
#
#
# .9245⋅Y_0,_NI__LIQUID⋅log(Y_0,_NI__LIQUID) + 1.0⋅Y_0,_NI__LIQUID⋅(-94001.1⋅log
#
#
#
#
# (2181) + 576262.463)

# %%
mod({'T':300,Y('LIQUID',0,'CR'):0.33, Y('LIQUID',0,'FE'):0.33, Y('LIQUID',0,'NI'):0.34})
# Out:
# -7245.5997⋅log(300) + 48046.2047519059

# %%
mod({'T':300,Y('LIQUID',0,'CR'):0.33, Y('LIQUID',0,'FE'):0.33, Y('LIQUID',0,'NI'):0.34}).evalf()
# Out:
# 6718.88016467164

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from numpy import linspace
x = []
y = []
temp = 1000 # Kelvin
for t in linspace(0,0.7):
    ni_content = 0.3
    fe_content = t
    cr_content = 1.0 - fe_content - ni_content
    x.append(fe_content)
    y.append(float(mod({'T':temp,Y('LIQUID',0,'CR'):cr_content, Y('LIQUID',0,'FE'):fe_content, Y('LIQUID',0,'NI'):ni_content})))
plt.plot(x, y)
plt.show()
